# %%
# %pylab
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
def demo(x):
    if x < 1:
        return 303
    else:
        return 293

# %%
x=linspace(0,2,1000)

# %%
base=[303,293,313,314,396,465,804,826,782,681,705,716,
     778,719,671,672,738,769,875,820,811,695,495,359]

# %%
x=linspace(0,24,num=24000)

# %%
y=[]
for i in base:
    y+=[i]*1000

# %%
len(y),len(x)
# Out:
# (24000, 24000)

# %%
# %matplotlib auto
plot(x,y)
# Out:
# Using matplotlib backend: Qt5Agg

# %%
from PIL import Image

# %%
pwd
# Out:
# 'C:\\Users\\gusto\\1plus1is2'

# %%
cd ..
# Out:
# C:\Users\gusto

# %%
cd Desktop/bing_pics/
# Out:
# C:\Users\gusto\Desktop\bing_pics

# %%
img=Image.open("2018-12-30.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x13F9DA73EB8>

# %%
img.width,img.height
# Out:
# (1920, 1080)

# %%
img.size
# Out:
# (1920, 1080)

# %%
img.crop?

# %%
Image?

# %%
def f(x):
    if x < 3:
        return x
    else:
        return f(x-1) + 2*f(x-2) + 3*f(x-3)

# %%
x=arange(0,100)

# %%
base=list(range(3))

# %%
n=100
while n > 0:
    n-=1
    base.append(base[-1]+2*base[-2]+3*base[-1])

# %%
base=base[:100]

# %%
len(x),len(base)
# Out:
# (100, 100)

# %%
plot(x,base)
